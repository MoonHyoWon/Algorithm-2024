# %% [markdown]
# ##### 예제 3.1
# ###### 1. 문제정의 : 리스트에 n개의 항목들이 들어 있다. 이들을 키(key)의 순서에 따라 오름차순으로 재배치하라.
# ###### 2. 알고리즘 설명 : 정렬이 안 된 리스트에서 최솟값이 선택되면 이 값을 새로운 리스트에 저장하는 것이 아니라 첫 번째 요소와 교환한다.
# ###### 3. 손으로 푼 예제 : 이중 for문을 이용하여 0부터 차례대로 원소 값을 비교하여 가장 작은 것이 있다면 위치를 바꾸는 문제이다.
# ###### 4. 알고리즘 개요(입력 변수, 출력, 알고리즘 개요) :
# ###### 4.1. 입력 변수 : [5, 3, 8, 4, 9, 1, 6, 2, 7] -> 정렬이 되지 않은 상태
# ###### 4.2. 출력 : [1, 2, 3, 4, 5, 6, 7, 8, 9] -> 정렬된 상태
# ###### 4.3. 알고리즘 개요 : 선택 정렬
# ###### 7. 수행 결과 : ![3_Quest1.png](attachment:3_Quest1.png)
# ###### 8. 복잡도 분석 : for문이 이중으로 반복되기 때문에 적어도 O(n^2)의 복잡도를 가지고 있다.

# %%
#알고리즘 코드
def selection_sort(A):
    n = len(A)
    for i in range(n-1):
        least = i
        for j in range(i+1, n):
            if(A[j]<A[least]):
                least = j
        A[i], A[least] = A[least], A[i]
        print("Step ", i+1, ": ", A)

data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
print("Original: ", data)
selection_sort(data)
print("Selection : ", data)
# Out:
# Original:  [5, 3, 8, 4, 9, 1, 6, 2, 7]
# Step  1 :  [1, 3, 8, 4, 9, 5, 6, 2, 7]
# Step  2 :  [1, 2, 8, 4, 9, 5, 6, 3, 7]
# Step  3 :  [1, 2, 3, 4, 9, 5, 6, 8, 7]
# Step  4 :  [1, 2, 3, 4, 9, 5, 6, 8, 7]
# Step  5 :  [1, 2, 3, 4, 5, 9, 6, 8, 7]
# Step  6 :  [1, 2, 3, 4, 5, 6, 9, 8, 7]
# Step  7 :  [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Step  8 :  [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Selection :  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#테스트 코드
def selection_sort(A):
    n = len(A)
    for i in range(n-1):
        least = i
        for j in range(i+1, n):
            if(A[j]<A[least]):
                least = j
        A[i], A[least] = A[least], A[i]
        print("Step ", i+1, ": ", A)

data = [3, 4, 2, 7, 8, 6, 9, 5, 1]
print("Original: ", data)
selection_sort(data)
print("Selection : ", data)
# Out:
# Original:  [3, 4, 2, 7, 8, 6, 9, 5, 1]
# Step  1 :  [1, 4, 2, 7, 8, 6, 9, 5, 3]
# Step  2 :  [1, 2, 4, 7, 8, 6, 9, 5, 3]
# Step  3 :  [1, 2, 3, 7, 8, 6, 9, 5, 4]
# Step  4 :  [1, 2, 3, 4, 8, 6, 9, 5, 7]
# Step  5 :  [1, 2, 3, 4, 5, 6, 9, 8, 7]
# Step  6 :  [1, 2, 3, 4, 5, 6, 9, 8, 7]
# Step  7 :  [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Step  8 :  [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Selection :  [1, 2, 3, 4, 5, 6, 7, 8, 9]
